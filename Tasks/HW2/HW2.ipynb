# %% [markdown]
# # Домашнее задание 2
#
# Задание следует выполнять в этой [тетрадке](https://colab.research.google.com/drive/1AdBbDOHBgfbjXyLsopYsJUhvKTEVuGvQ?usp=sharing), скопировав или скачав её к себе. Сдавайте задание в эту [форму](https://docs.google.com/forms/d/e/1FAIpQLSfWLN7CKHfb4LnAfEpxmvSBFWIPr9HeDUzbAaTmulRfDTW8kA/viewform). Дедлайн — 20 марта, 23.59. Задание можно сдать с задержкой (но не позже 4 дней после экзамена — и тогда к моменту экзамена, конечно, не будет полностью известна накопленная оценка), однако каждые 2 дня итоговая оценка понижается на 1 балл.
#
#
# Для каждого задания указана оценка, которая за неё даётся. Чтобы тетрадка получила оценку, выше 4, тетрадка должна отрабатывать без ошибок при запуске целиком (пункт меню _Среда выполнения_ --> _Выполнить всё_). Пожалуйста, проверьте перед сдачей, что это так.

# %% [markdown]
# ## Задание 1: Выгрузка информации из Интернета (6 баллов)
#
# Выберите любой новостной портал, который вам нравится, и создаёте на его основе небольшой корпус новостей. Это не должен быть портал, который приводится в тетрадках из практических занятий или портал, выбранный вашими коллегами. Чтобы гарантировать последнее, впишите свой портал в [эту таблицу](https://docs.google.com/spreadsheets/d/1O5-oJ-9zX98IM8050EPp0f7WMsMPL4OZ39HA45ZoVFI/edit?usp=sharing), предварительно проверив, что он там отсутствует. Пожалуйста, не пишите туда больше ничего (я рассчитываю на вашу адекватность, но такой расчёт не всегда оправдывается...) и не меняйте записи других людей — по истории версий всё можно отследить.
#
# Объём созданного корпуса должен соответствовать одному из следующих пунктов:
#
# - скачаны все новости за один любой день (можете как установить одну конкретную дату, так и выкачивать всё на текущий / вчерашний день относительно дня запуска тетрадки)
# - или скачать ровно 10 новостей.
#
# Для каждой новости в дополнение к тексту выгрузите заголовок и дату публикации (если они отсутствуют на выбранном ресурсе, замените его на другой) и представьте выгруженные новости в виде таблицы, где заголовки, даты и тексты представлены в отдельных столбцах с заголовками.
#
# Оценивание (обратите внимание, что задание можно сделать частично):
#
# |  Элемент оценивания | Балл  |
# |---|---|
# |  Скачана хоть одна страница |  1 балл |
# |  Скачано требуемое количество страниц | 1 балл  |
# |  Набор страниц не задаётся перечислением url-адресов вручную, а может масштабироваться (например, вы подбираете адреса по алгоритму или извлекаете их из какого-то места на странице портала) |  1 балл |
# |  Из страницы / страниц извлечена необходимая информация | 2&nbsp;балла  |
# |  Новости представлены в виде таблицы, таблица выведена |  1 балл |

# %%
#Впишите сюда свой код — если потребуется, можно и нужно добавить больше ячеек

# %% [markdown]
# ## Задание 2: Аналитическая статистика (4 балла)
#
# Решите следующие две задачи, предполагающие применение аналитической статистики. Для каждого из заданий укажите:
#
# - нулевую гипотезу и альтернативную гипотезу;
# - статистический критерий, который вы использовали;
# - тип критерия, если применимо (one-tailed / two-tailed; одновыборочный / двухвыборочный);
# - способ, с помощью которого вы его применяли: конкретный сайт или функция Питона;
# - результаты применения статистического критерия (p-value)
# - осмысление его в терминах нулевой / альтернативной гипотез с использованием уровня значимости _p = 0.05_;
# - интерпретацию этих результатов с точки зрения содержательного вопроса, который ставится в задаче.
#
# В каждом пункте достаточный ответ содержит от одного слова / числа до пары предложений.
#
# ### Задача 1 (2 балла)
#
# Вы подсчитали, насколько часто встреваются в корпусе слова _как_ и _так_ сами по себе, а также в сочетании со словом _же_ и получили результаты, представленные в [таблице](https://docs.google.com/spreadsheets/d/1jT-zSexoN9TqdXkrf5YBDChSpglCkDlB8ocf87aY1B0/edit?usp=sharing) на листе с вашей фамилией. Если вас в таблице нет, напишите преподавателю, чтобы там появиться.
#
# Вы хотите проверить, правда ли так встречается перед же значимо чаще.
#
# Дополнительный комментарий 1. Это наблюдение интересно, потому что далее его можно обобщить: слово же имеет несколько функций, и одна из них — особое выделение вопроса, которая доступна только для вопросительных слов. Другие функции, наоборот, к вопросительным словами не применимы (например, в значении повторения какого-то участника или обстоятельства ситуации: _В том году он был в своей лучшей форме, тогда же и выиграл соревнования_). Интересный в этом случае вопрос — насколько отличается сочетаемость с _же_ у вопросительных и у других слов. Понятно при этом, что ответ на такой общий вопрос потребует анализа большего числа единиц, и не парами, а в какой-то более общей постановке задачи.
#
# Дополнительный комментарий 2. Все приведённые значения соответствуют реальным значениям в корпусе, но смоделированы для корпусов разных размеров.

# %%
#Впишите сюда свой код, если он потребуется

# %% [markdown]
#     Место для ответа с рассуждениями и пояснениями — не забудьте стереть этот текст

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Вам стало интересно, какого возраста люди читают два разных комикса. Чтобы узнать это, вы решили разметить возраст тех, кто прокомментировал запись в сообществе социальной сети, посвящённой этому ресурсу, и получили результаты, представленные в [таблице](https://docs.google.com/spreadsheets/d/1JqlnCLtp8sEa_rYkt4GDUZumEvOytJ-zQEBZA3WG0Mk/edit?usp=sharing) на листе с вашей фамилией. Если вас в таблице нет, напишите преподавателю, чтобы там появиться.
#
# Правда ли, что возраст тех, кто комментирует каждый из романов, отличается?

# %%
#Впишите сюда свой код, если он потребуется

# %% [markdown]
#     Место для ответа с рассуждениями и пояснениями — не забудьте стереть этот текст
